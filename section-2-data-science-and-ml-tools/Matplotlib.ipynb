# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=[1,2,3,4]
y=[11,22,73,44]
plt.plot(x,y)
plt.show()

# %%
#1st method pyplot
fig= plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])

# %%
#3rd method
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x,y);
ax.set(title='Simple Plot', xlabel='x-axis', ylabel='y-axis')
fig.savefig('../images/sample-plot.png')

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title='Mio grafico',xlabel='x-axis', ylabel='y-axis')
# Out:
# [Text(0, 0.5, 'y-axis'), Text(0.5, 0, 'x-axis'), Text(0.5, 1.0, 'Mio grafico')]

# %%
import numpy as np
x = np.linspace(0,10,40)

# %%
fig, ax = plt.subplots()  #lineplot
ax.plot(x,x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x, x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_butter = {"Almond":10, 'Peanut': 8, 'Jelly': 4}
fig,ax = plt.subplots()
ax.bar(nut_butter.keys(), nut_butter.values())
ax.set(title='Butter Store Price', ylabel ='Price');

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x,x**3)
ax.set(title='Cubico', xlabel='Asse X', ylabel='Asse Y')
# Out:
# [Text(0, 0.5, 'Asse Y'), Text(0.5, 0, 'Asse X'), Text(0.5, 1.0, 'Cubico')]

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(x,x**1.7)

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.bar(list(nut_butter.keys()),list(nut_butter.values()));

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter.keys()), list(nut_butter.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
z= np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(z);

# %% [markdown]
# # Subplots

# %%
fig, ((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,ncols=2, figsize=(10,5))
ax1.plot(x,x**2)
ax4.hist(z)
ax2.scatter(np.random.random(30),np.random.random(30))
ax3.barh(list(nut_butter.keys()), list(nut_butter.values()));

# %%
import pandas as pd
car = pd.read_csv('../data/car-sales.csv')

# %%
car['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car['Price']= car['Price'].str.replace('[\$\,\.]','')

# %%
car['Price']=car['Price'].str[:-2]

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car['Sale Date'] = pd.date_range("1/1/2020",periods=10)

# %%
car['Total Sales']= car['Price'].astype(int).cumsum()

# %%
car.plot(x='Sale Date', y='Total Sales');
car['Price']=car['Price'].astype(int)

# %%
car.plot(x='Odometer (KM)', y= 'Price', kind='scatter');

# %%
x = np.random.rand(10,4)

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.791297  0.792578  0.919064  0.936756
# 1  0.119544  0.853684  0.720277  0.329671
# 2  0.030357  0.761366  0.362172  0.319092
# 3  0.832038  0.190813  0.024910  0.503726
# 4  0.151434  0.667688  0.657785  0.735308
# 5  0.054700  0.169877  0.440456  0.960769
# 6  0.231255  0.979302  0.447692  0.802132
# 7  0.321140  0.034838  0.815039  0.789222
# 8  0.444722  0.624743  0.052941  0.057901
# 9  0.053859  0.606605  0.174886  0.895301

# %%
df.plot.bar()

# %%
car.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
car['Odometer (KM)'].plot.hist(bins=20);

# %%
heart = pd.read_csv('../data/heart-disease.csv')
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart['age'].hist(bins=20)

# %%
heart.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# # OO Method

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart[heart['age']>50]
len(heart)
len(over_50)
# Out:
# 208

# %%
#pyplot method
over_50.plot(kind='scatter',x='age',y='chol', c='target')

# %%
# oo method
fig, ax = plt.subplots(figsize=(10,10))
over_50.plot(kind='scatter',x='age', y='chol', c='target',ax=ax)
#ax.set_xlim(28,80);

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], c=over_50['target'])
ax.set(title=' Heart disease and Cholesterol Level', xlabel= 'Age', ylabel= 'Cholesterol')
ax.legend(*scatter.legend_elements(), title='Target');

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10,10))
fig.suptitle('Heart Disease Analysis',fontsize=16, fontweight='bold')

scatter = ax0.scatter(x=over_50['age'], y=over_50['chol'],c=over_50['target'])
ax0.set(title='Heart Disease and Cholesterol', xlabel='Age', ylabel ='Cholesterol')
ax0.legend(*scatter.legend_elements(), title='Target')
ax0.axhline(y=over_50['chol'].mean(), linestyle='--');

scatter = ax1.scatter(x=over_50['age'], y=over_50['thalach'],c=over_50['target'])
ax1.set(title='Heart Disease and Max Heart Rate', xlabel='Age', ylabel='Heart Rate')
ax1.legend(*scatter.legend_elements(), title='Target')
ax1.axhline(y=over_50['thalach'].mean(), linestyle='--');

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
x=np.random.randn(10,4)

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.630024 -0.416450 -0.073944  1.261943
# 1  0.569972  0.567062 -1.160395 -0.232055
# 2  0.021465 -0.818049 -1.841212  0.695272
# 3  1.908999  1.403452 -1.081754 -1.469301
# 4  2.233057 -0.023306 -0.569427  0.297822
# 5  0.597343  1.396870 -0.524016 -0.040001
# 6 -0.274942  0.805451 -0.425591  0.085081
# 7 -0.227048 -1.242290  0.559118  0.606749
# 8 -1.361489  0.300743 -2.487549  0.673222
# 9  0.579848 -2.546471  0.737669  0.631744

# %%
ax = df.plot(kind='bar')
ax.set(title='Random Numbers', xlabel='Asse X', ylabel='Asse Y')
type(ax)
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')
fig.suptitle("Heart Disease", fontsize=16)
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10,10),sharex=True)
scatter = ax0.scatter(x=over_50['age'], y=over_50['chol'], c=over_50['target'],
          cmap='spring')
ax0.set(title='Heart Disease and Cholesterol',  ylabel='Cholesterol')
ax0.legend(*scatter.legend_elements(), title='Target')
ax0.axhline(over_50['chol'].mean(),linestyle='--');
ax0.set_xlim(50,80)

scatter= ax1.scatter(x=over_50['age'],y= over_50['thalach'], c=over_50['target']
                    ,cmap='winter')
ax1.set(title='Heart Disease and Max Heart Rate', xlabel ='Age', ylabel='Heart Rate')
ax1.legend(*scatter.legend_elements(), title='Target')
ax1.set_ylim(60,200)
# Out:
# (60.0, 200.0)
